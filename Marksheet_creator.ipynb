# %%
mark = float(input("Enter your marks: "))

if mark > 90:
  print("Grade : O")
elif mark >= 80 and mark < 90:
  print("Grade : A")
elif mark >= 70 and mark < 80:
  print("Grade : B")
elif mark >= 60 and mark < 70:
  print("Grade : C")
elif mark >= 50 and mark < 60:
  print("Grade : D")
elif mark >= 40 and mark < 50:
  print("Grade : E")
else:
  print("Fail")
# Out:
# Enter your marks: 99
# Grade : O

# %%
marks = float(input("Enter your marks in Computer Science: "))

if marks > 90:
    print("Grade: O")
elif marks >= 80 and marks < 90:
    print("Grade: A+")
elif marks >= 70 and marks < 80:
    print("Grade: A")
elif marks >= 60 and marks < 70:
    print("Grade: B+")
elif marks >= 50 and marks < 60:
    print("Grade: B")
elif marks >= 40 and marks < 50:
    print("Grade: C")
else:
    print("Grade: F")
# Out:
# Enter your marks in Computer Science: 55
# Grade: B

# %%
#python program for student grade

e = float(input("Enter your English mark : "))
m = float(input("Enter your Maths mark : "))
s = float(input("Enter your Science mark : "))
h = float(input("Enter your Hindi mark : "))
g = float(input("Enter your Gujrati mark : "))
d = float(input("Enter your Data Analytics mark : "))

total = e + m + s + h + g + d
percentage = (total / 600) * 100

print("Total Marks = %.2f"  %total)
print("Marks Percentage = %.2f"  %percentage)

if percentage >= 90:
  print("Grade O")
elif percentage >= 80:
  print("Grade A")
elif percentage >= 70:
  print("Grade B")
elif percentage >= 60:
  print("Grade C")
elif percentage >= 50:
  print("Grade D")
elif percentage >= 40:
  print("Grade E")
  print("Need improvement")
else:
  print("Fail")
  print("Need improvement")
# Out:
# Enter your English mark : 89
# Enter your Maths mark : 98
# Enter your Science mark : 95
# Enter your Hindi mark : 96
# Enter your Gujrati mark : 97
# Enter your Data Analytics mark : 99
# Total Marks = 574.00
# Marks Percentage = 95.67
# Grade O
